# %% [markdown]
# # Experiment 1(꺾은선)
#
# 김보람
# 2024-04-03

# %%
import pandas as pd
import numpy as np
#import sklearn
import pickle 
import time 
import datetime
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pd.options.plotting.backend = "plotly"
pio.templates.default = "plotly_white"

# %%
df = pd.read_csv('./240404_meged.csv')
df = df[['L2' not in l and 'L1' not in l for l in df.model]]
#df['diff'] = abs(merged_df['train_frate'] - merged_df['test_frate'])
df = df[(df.test_frate <= 0.005) & (0.009 < df.train_frate) & (df.train_frate < 0.51)]

# %%
fig = px.scatter(
    df,
    x='train_frate',y='auc',
    color='method',
    hover_data='model',
    opacity=0.2,
    #---#
    width = 750,
    height = 800  
)
fig.data[3]['marker']['opacity'] = 0.7
fig.data[3]['marker']['size'] = 9
fig
# Out:
# <div>                            <div id="daf7b906-93e7-4119-93e7-f69cb1c4c123" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daf7b906-93e7-4119-93e7-f69cb1c4c123")) {                    Plotly.newPlot(                        "daf7b906-93e7-4119-93e7-f69cb1c4c123",                        [{"customdata":[["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ABOD"],["COPOD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN"],["LODA"],["LOF"],["MAD"],["MCD"],["OCSVM"],["PCA"],["ROD"],["ABOD"],["COPOD"],["ECOD"],["GMM"],["HBOS"],["IForest"],["INNE"],["KDE"],["KNN